# %%
from preprocessing import (
    load_data,
    get_summary,
    find_nans_per_column,
    drop_cols,
    forward_fill_prices,
)
from constants import FILENAME

df = load_data(filename=FILENAME)

get_summary(df)  # print a big summary (and ask ai about it)

cols_to_drop = find_nans_per_column(df)

df = drop_cols(df, cols_to_drop)  # if you so choose

# or just fill every NaN with the most recent valid value
df = forward_fill_prices(df)
