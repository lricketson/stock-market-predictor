# %%
from preprocessing import (
    load_data,
    get_summary,
    find_nans_per_column,
    drop_cols,
    forward_fill_prices,
)
from constants import TRAIN_FILENAME

df = load_data(filename=TRAIN_FILENAME)

get_summary(df)  # print a big summary

cols_to_drop = find_nans_per_column(df)

df = drop_cols(df, cols_to_drop)  # if you so choose

# or just fill every NaN with the most recent valid value
df = forward_fill_prices(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 42 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      10000 non-null  int64
#  1   p1      10000 non-null  float64
#  2   p2      10000 non-null  float64
#  3   p3      10000 non-null  float64
#  4   p4      10000 non-null  float64
#  5   p5      10000 non-null  float64
#  6   p6      10000 non-null  float64
#  7   p7      10000 non-null  float64
#  8   p8      10000 non-null  float64
#  9   p9      10000 non-null  float64
#  10  p10     10000 non-null  float64
#  11  p11     10000 non-null  float64
#  12  p12     10000 non-null  float64
#  13  p13     10000 non-null  float64
#  14  p14     10000 non-null  float64
#  15  p15     10000 non-null  float64
#  16  p16     10000 non-null  float64
#  17  p17     10000 non-null  float64
#  18  p18     10000 non-null  float64
#  19  p19     10000 non-null  float64
#  20  p20     10000 non-null  float64
#  21  p21     10000 non-null  float64
#  22  p22     10000 non-null  float64
#  23  p23     10000 non-null  float64
#  24  p24     10000 non-null  float64
#  25  p25     10000 non-null  float64
#  26  p26     10000 non-null  float64
#  27  p27     10000 non-null  float64
#  28  p28     10000 non-null  float64
#  29  p29     10000 non-null  float64
#  30  p30     10000 non-null  float64
#  31  p31     10000 non-null  float64
#  32  p32     10000 non-null  float64
#  33  p33     10000 non-null  float64
#  34  p34     10000 non-null  float64
#  35  p35     10000 non-null  float64
#  36  p36     10000 non-null  float64
#  37  p37     10000 non-null  float64
#  38  p38     10000 non-null  float64
#  39  p39     10000 non-null  float64
#  40  p40     10000 non-null  float64
#  41  p50     10000 non-null  float64
# dtypes: float64(41), int64(1)
# memory usage: 3.2 MB
# df.info(): None
#
# DataFrame has 10000 rows and 42 columns.
#
# Summary stats:                 ID            p1            p2            p3            p4  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    4999.50000    100.001667     99.998473     99.969712     99.931457
# std     2886.89568      6.138997      7.148818      8.315946      9.509276
# min        0.00000     85.290000     79.710000     73.920000     72.780000
# 25%     2499.75000     94.980000     94.727500     93.960000     93.137500
# 50%     4999.50000     99.970000    100.050000    100.005000     99.890000
# 75%     7499.25000    105.090000    105.352500    105.980000    106.842500
# max     9999.00000    114.810000    120.300000    126.890000    128.610000
#
#                  p5            p6            p7            p8            p9  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      99.880003     99.865940     99.848891     99.815983     99.794084
# std       10.682264     11.775728     12.894025     13.961831     14.919703
# min       67.350000     65.350000     60.580000     61.510000     55.330000
# 25%       92.160000     91.340000     90.410000     89.500000     88.880000
# 50%       99.985000    100.040000     99.900000    100.050000     99.975000
# 75%      107.662500    108.622500    109.320000    110.002500    110.660000
# max      129.780000    132.080000    137.220000    138.870000    146.430000
#
#        ...           p32           p33           p34           p35  \
# count  ...  10000.000000  10000.000000  10000.000000  10000.000000
# mean   ...     99.604238     99.577894     99.560079     99.540622
# std    ...     29.937890     30.401620     30.856418     31.352193
# min    ...      4.570000      3.230000      2.910000      0.000000
# 25%    ...     78.605000     78.340000     77.875000     77.565000
# 50%    ...     99.825000     99.900000     99.670000     99.705000
# 75%    ...    120.577500    120.940000    121.515000    121.830000
# max    ...    196.200000    195.640000    199.330000    199.640000
#
#                 p36           p37           p38           p39           p40  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      99.528412     99.514691     99.513920     99.524270     99.537554
# std       31.880285     32.373004     32.903792     33.414083     33.929590
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       77.300000     76.977500     76.610000     76.347500     75.917500
# 50%       99.595000     99.515000     99.465000     99.685000     99.665000
# 75%      122.095000    122.412500    122.822500    122.850000    123.117500
# max      203.130000    207.050000    211.140000    215.640000    220.070000
#
#                 p50
# count  10000.000000
# mean      99.580297
# std       38.512791
# min        0.000000
# 25%       72.517500
# 50%       99.835000
# 75%      126.075000
# max      249.950000
#
# [8 rows x 42 columns]
#
# Number of NaNs: ID     0
# p1     0
# p2     0
# p3     0
# p4     0
# p5     0
# p6     0
# p7     0
# p8     0
# p9     0
# p10    0
# p11    0
# p12    0
# p13    0
# p14    0
# p15    0
# p16    0
# p17    0
# p18    0
# p19    0
# p20    0
# p21    0
# p22    0
# p23    0
# p24    0
# p25    0
# p26    0
# p27    0
# p28    0
# p29    0
# p30    0
# p31    0
# p32    0
# p33    0
# p34    0
# p35    0
# p36    0
# p37    0
# p38    0
# p39    0
# p40    0
# p50    0
# dtype: int64
#
# Data types: ID       int64
# p1     float64
# p2     float64
# p3     float64
# p4     float64
# p5     float64
# p6     float64
# p7     float64
# p8     float64
# p9     float64
# p10    float64
# p11    float64
# p12    float64
# p13    float64
# p14    float64
# p15    float64
# p16    float64
# p17    float64
# p18    float64
# p19    float64
# p20    float64
# p21    float64
# p22    float64
# p23    float64
# p24    float64
# p25    float64
# p26    float64
# p27    float64
# p28    float64
# p29    float64
# p30    float64
# p31    float64
# p32    float64
# p33    float64
# p34    float64
# p35    float64
# p36    float64
# p37    float64
# p38    float64
# p39    float64
# p40    float64
# p50    float64
# dtype: object
#
# df.head():    ID      p1      p2      p3      p4      p5      p6      p7      p8      p9  \
# 0   0   95.44   98.63  102.79   99.71   96.48   93.32   88.99   84.61   83.39
# 1   1  104.11  104.35  104.32  104.55  103.28   99.04   96.37   97.07   96.48
# 2   2  109.64  109.58  110.92  108.53  104.98  102.64  107.21  107.96  114.28
# 3   3  104.99  103.48  104.35  104.64  104.90  101.73  100.89  104.89  105.02
# 4   4  108.99  102.78   99.99   98.17   94.41   95.75   96.35   98.10   98.85
#
#    ...     p32     p33     p34     p35     p36     p37     p38     p39  \
# 0  ...   90.57   86.88   86.27   83.42   80.25   76.95   73.69   69.15
# 1  ...   65.94   70.90   70.07   69.43   69.45   68.24   68.39   72.00
# 2  ...  117.49  117.19  120.93  122.84  124.58  126.50  130.17  131.77
# 3  ...  106.08  108.09  108.14  109.10  108.68  111.60  115.23  117.05
# 4  ...  100.85   97.59   96.23   94.31   97.42  100.85  104.61  108.91
#
#       p40     p50
# 0   67.07   56.62
# 1   71.67   52.60
# 2  136.22  125.94
# 3  119.02  138.97
# 4  111.31  120.89
#
# [5 rows x 42 columns]
# Column ID is 0.0% missing values (total count 0).
# Column p1 is 0.0% missing values (total count 0).
# Column p2 is 0.0% missing values (total count 0).
# Column p3 is 0.0% missing values (total count 0).
# Column p4 is 0.0% missing values (total count 0).
# Column p5 is 0.0% missing values (total count 0).
# Column p6 is 0.0% missing values (total count 0).
# Column p7 is 0.0% missing values (total count 0).
# Column p8 is 0.0% missing values (total count 0).
# Column p9 is 0.0% missing values (total count 0).
# Column p10 is 0.0% missing values (total count 0).
# Column p11 is 0.0% missing values (total count 0).
# Column p12 is 0.0% missing values (total count 0).
# Column p13 is 0.0% missing values (total count 0).
# Column p14 is 0.0% missing values (total count 0).
# Column p15 is 0.0% missing values (total count 0).
# Column p16 is 0.0% missing values (total count 0).
# Column p17 is 0.0% missing values (total count 0).
# Column p18 is 0.0% missing values (total count 0).
# Column p19 is 0.0% missing values (total count 0).
# Column p20 is 0.0% missing values (total count 0).
# Column p21 is 0.0% missing values (total count 0).
# Column p22 is 0.0% missing values (total count 0).
# Column p23 is 0.0% missing values (total count 0).
# Column p24 is 0.0% missing values (total count 0).
# Column p25 is 0.0% missing values (total count 0).
# Column p26 is 0.0% missing values (total count 0).
# Column p27 is 0.0% missing values (total count 0).
# Column p28 is 0.0% missing values (total count 0).
# Column p29 is 0.0% missing values (total count 0).
# Column p30 is 0.0% missing values (total count 0).
# Column p31 is 0.0% missing values (total count 0).
# Column p32 is 0.0% missing values (total count 0).
# Column p33 is 0.0% missing values (total count 0).
# Column p34 is 0.0% missing values (total count 0).
# Column p35 is 0.0% missing values (total count 0).
# Column p36 is 0.0% missing values (total count 0).
# Column p37 is 0.0% missing values (total count 0).
# Column p38 is 0.0% missing values (total count 0).
# Column p39 is 0.0% missing values (total count 0).
# Column p40 is 0.0% missing values (total count 0).
# Column p50 is 0.0% missing values (total count 0).
# ------------------------------------------------------------
# Cols recommended to drop: []
